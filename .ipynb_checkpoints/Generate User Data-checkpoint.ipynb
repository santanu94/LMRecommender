# %% [markdown]
# ### Format and Tokenize movie information

# %%
import pandas as pd
import numpy as np
import ast
import random
import json

# %%
dataset = pd.read_csv('tmdb_5000_movies.csv')
dataset_bkp = dataset.copy()

# %% [markdown]
# I want to recommend based on the genre, keywords and the language of the movie

# %%
dataset = dataset.drop(columns=['id', 'budget', 'homepage', 'original_title', 'overview', 'release_date', 'popularity', 'production_companies', 'revenue', 'runtime', 'tagline', 'title', 'vote_average', 'vote_count', 'status', 'spoken_languages', 'production_countries'])
dataset.head()
# Out:
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords original_language
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en

# %%
def unpack(row):
    arr = []
    for item in ast.literal_eval(row):
        arr.append(item['name'].lower())
    return arr

# %%
dataset['genres'] = dataset['genres'].apply(unpack)
dataset['keywords'] = dataset['keywords'].apply(unpack)
dataset['original_language'] = dataset['original_language'].apply(lambda x: [x])
dataset.head()
# Out:
#                                           genres  \
# 0  [action, adventure, fantasy, science fiction]
# 1                   [adventure, fantasy, action]
# 2                     [action, adventure, crime]
# 3               [action, crime, drama, thriller]
# 4           [action, adventure, science fiction]
#
#                                             keywords original_language
# 0  [culture clash, future, space war, space colon...              [en]
# 1  [ocean, drug abuse, exotic island, east india ...              [en]
# 2  [spy, based on novel, secret agent, sequel, mi...              [en]
# 3  [dc comics, crime fighter, terrorist, secret i...              [en]
# 4  [based on novel, mars, medallion, space travel...              [en]

# %%
list_gen = []
list_keywords = []
list_lang = []

dataset['genres'].apply(lambda col: list_gen.extend(col))
dataset['keywords'].apply(lambda col: list_keywords.extend(col))
dataset['original_language'].apply(lambda col: list_lang.extend(col))

list_gen = list(dict.fromkeys(list_gen))
list_keywords = list(dict.fromkeys(list_keywords))
list_lang = list(dict.fromkeys(list_lang))

print('No of unique genres ->', len(list_gen))
print('No of unique keywords ->', len(list_keywords))
print('No of unique languages ->', len(list_lang))
# Out:
# No of unique genres -> 20
# No of unique keywords -> 9813
# No of unique languages -> 37

# %%
org_values_list = list_gen + list_keywords + list_lang
org_values_list = list(dict.fromkeys(org_values_list))
all_tokens_list = ['tok' + str(i) for i in range(len(org_values_list))]

token_to_value = dict(zip(all_tokens_list, org_values_list))
value_to_token = dict(zip(org_values_list, all_tokens_list))

# %%
value_to_token
# Out:
# {'action': 'tok0',
#  'adventure': 'tok1',
#  'fantasy': 'tok2',
#  'science fiction': 'tok3',
#  'crime': 'tok4',
#  'drama': 'tok5',
#  'thriller': 'tok6',
#  'animation': 'tok7',
#  'family': 'tok8',
#  'western': 'tok9',
#  'comedy': 'tok10',
#  'romance': 'tok11',
#  'horror': 'tok12',
#  'mystery': 'tok13',
#  'history': 'tok14',
#  'war': 'tok15',
#  'music': 'tok16',
#  'documentary': 'tok17',
#  'foreign': 'tok18',
#  'tv movie': 'tok19',
#  'culture clash': 'tok20',
#  'future': 'tok21',
#  'space war': 'tok22',
#  'space colony': 'tok23',
#  'society': 'tok24',
#  'space travel': 'tok25',
#  'futuristic': 'tok26',
#  'space': 'tok27',
#  'alien': 'tok28',
#  'tribe': 'tok29',
#  'alien planet': 'tok30',
#  'cgi': 'tok31',
#  'marine': 'tok32',
#  'soldier': 'tok33',
#  'battle': 'tok34',
#  'love affair': 'tok35',
#  'anti war': 'tok36',
#  'power relations': 'tok37',
#  'mind and soul': 'tok38',
#  '3d': 'tok39',
#  'ocean': 'tok40',
#  'drug abuse': 'tok41',
#  'exotic island': 'tok42',
#  'east india trading company': 'tok43',
#  "love of one's life": 'tok44',
#  'traitor': 'tok45',
#  'shipwreck': 'tok46',
#  'strong woman': 'tok47',
#  'ship': 'tok48',
#  'alliance': 'tok49',
#  'calypso': 'tok50',
#  'afterlife': 'tok51',
#  'fighter': 'tok52',
#  'pirate': 'tok53',
#  'swashbuckler': 'tok54',
#  'aftercreditsstinger': 'tok55',
#  'spy': 'tok56',
#  'based on novel': 'tok57',
#  'secret agent': 'tok58',
#  'sequel': 'tok59',
#  'mi6': 'tok60',
#  'british secret service': 'tok61',
#  'united kingdom': 'tok62',
#  'dc comics': 'tok63',
#  'crime fighter': 'tok64',
#  'terrorist': 'tok65',
#  'secret identity': 'tok66',
#  'burglar': 'tok67',
#  'hostage drama': 'tok68',
#  'time bomb': 'tok69',
#  'gotham city': 'tok70',
#  'vigilante': 'tok71',
#  'cover-up': 'tok72',
#  'superhero': 'tok73',
#  'villainess': 'tok74',
#  'tragic hero': 'tok75',
#  'terrorism': 'tok76',
#  'destruction': 'tok77',
#  'catwoman': 'tok78',
#  'cat burglar': 'tok79',
#  'imax': 'tok80',
#  'flood': 'tok81',
#  'criminal underworld': 'tok82',
#  'batman': 'tok83',
#  'mars': 'tok84',
#  'medallion': 'tok85',
#  'princess': 'tok86',
#  'steampunk': 'tok87',
#  'martian': 'tok88',
#  'escape': 'tok89',
#  'edgar rice burroughs': 'tok90',
#  'alien race': 'tok91',
#  'superhuman strength': 'tok92',
#  'mars civilization': 'tok93',
#  'sword and planet': 'tok94',
#  '19th century': 'tok95',
#  'dual identity': 'tok96',
#  'amnesia': 'tok97',
#  'sandstorm': 'tok98',
#  'forgiveness': 'tok99',
#  'spider': 'tok100',
#  'wretch': 'tok101',
#  'death of a friend': 'tok102',
#  'egomania': 'tok103',
#  'sand': 'tok104',
#  'narcism': 'tok105',
#  'hostility': 'tok106',
#  'marvel comic': 'tok107',
#  'revenge': 'tok108',
#  'hostage': 'tok109',
#  'magic': 'tok110',
#  'horse': 'tok111',
#  'fairy tale': 'tok112',
#  'musical': 'tok113',
#  'tower': 'tok114',
#  'blonde woman': 'tok115',
#  'selfishness': 'tok116',
#  'healing power': 'tok117',
#  'based on fairy tale': 'tok118',
#  'duringcreditsstinger': 'tok119',
#  'healing gift': 'tok120',
#  'animal sidekick': 'tok121',
#  'based on comic book': 'tok122',
#  'vision': 'tok123',
#  'superhero team': 'tok124',
#  'marvel cinematic universe': 'tok125',
#  'witch': 'tok126',
#  'broom': 'tok127',
#  'school of witchcraft': 'tok128',
#  'wizardry': 'tok129',
#  'apparition': 'tok130',
#  'teenage crush': 'tok131',
#  'werewolf': 'tok132',
#  'super powers': 'tok133',
#  'clark kent': 'tok134',
#  'bruce wayne': 'tok135',
#  'dc extended universe': 'tok136',
#  'saving the world': 'tok137',
#  'invulnerability': 'tok138',
#  'kryptonite': 'tok139',
#  'lex luthor': 'tok140',
#  'killing': 'tok141',
#  'undercover': 'tok142',
#  'fortune teller': 'tok143',
#  'bondage': 'tok144',
#  'monster': 'tok145',
#  'captain': 'tok146',
#  'card game': 'tok147',
#  'compass': 'tok148',
#  'daughter': 'tok149',
#  'texas': 'tok150',
#  'survivor': 'tok151',
#  'texas ranger': 'tok152',
#  'partner': 'tok153',
#  'outlaw': 'tok154',
#  'lawyer': 'tok155',
#  'train': 'tok156',
#  'lone ranger': 'tok157',
#  'comanche': 'tok158',
#  'the lone ranger': 'tok159',
#  'tonto': 'tok160',
#  'superhuman': 'tok161',
#  'alien invasion': 'tok162',
#  'reboot': 'tok163',
#  'fictional place': 'tok164',
#  'brother sister relationship': 'tok165',
#  'lion': 'tok166',
#  'human being': 'tok167',
#  'leap in time': 'tok168',
#  'matter of life and death': 'tok169',
#  'faith': 'tok170',
#  'uncle': 'tok171',
#  'narnia': 'tok172',
#  'fantasy world': 'tok173',
#  'new york': 'tok174',
#  'shield': 'tok175',
#  'sea': 'tok176',
#  'mutiny': 'tok177',
#  'sword': 'tok178',
#  'prime minister': 'tok179',
#  'sailing': 'tok180',
#  'silver': 'tok181',
#  'duke': 'tok182',
#  'mermaid': 'tok183',
#  'time travel': 'tok184',
#  'time machine': 'tok185',
#  'fictional government agency': 'tok186',
#  'seeing the future': 'tok187',
#  'changing history': 'tok188',
#  'corruption': 'tok189',
#  'elves': 'tok190',
#  'dwarves': 'tok191',
#  'orcs': 'tok192',
#  'middle-earth (tolkien)': 'tok193',
#  'hobbit': 'tok194',
#  'dragon': 'tok195',
#  'unlikely friendship': 'tok196',
#  'epic battle': 'tok197',
#  'sword and sorcery': 'tok198',
#  'loss of father': 'tok199',
#  'serum': 'tok200',
#  'scientific experiment': 'tok201',
#  'spider bite': 'tok202',
#  'masked vigilante': 'tok203',
#  'genetic engineering': 'tok204',
#  'social outcast': 'tok205',
#  'robin hood': 'tok206',
#  'archer': 'tok207',
#  'knight': 'tok208',
#  'sherwood forest': 'tok209',
#  'bow and arrow': 'tok210',
#  'middle ages': 'tok211',
#  'medieval': 'tok212',
#  'king of england': 'tok213',
#  'wizard': 'tok214',
#  'england': 'tok215',
#  'experiment': 'tok216',
#  'lordship': 'tok217',
#  'polar bear': 'tok218',
#  'orphan': 'tok219',
#  'animal': 'tok220',
#  'based on young adult novel': 'tok221',
#  'film business': 'tok222',
#  'screenplay': 'tok223',
#  'show business': 'tok224',
#  'film making': 'tok225',
#  'film producer': 'tok226',
#  'indigenous': 'tok227',
#  'dinosaur': 'tok228',
#  'iceberg': 'tok229',
#  'panic': 'tok230',
#  'titanic': 'tok231',
#  'ocean liner': 'tok232',
#  'epic': 'tok233',
#  'rich woman - poor man': 'tok234',
#  'love': 'tok235',
#  'disaster': 'tok236',
#  'tragic love': 'tok237',
#  'class differences': 'tok238',
#  'star crossed lovers': 'tok239',
#  'steerage': 'tok240',
#  'salvage': 'tok241',
#  'rich snob': 'tok242',
#  '1910s': 'tok243',
#  'civil war': 'tok244',
#  'fight': 'tok245',
#  'u.s. navy': 'tok246',
#  'mind reading': 'tok247',
#  'hong kong': 'tok248',
#  'soccer': 'tok249',
#  'scientist': 'tok250',
#  'fictional war': 'tok251',
#  'naval': 'tok252',
#  'armada': 'tok253',
#  'battleship': 'tok254',
#  'naval combat': 'tok255',
#  'jds myoko': 'tok256',
#  'lost communication': 'tok257',
#  'taser': 'tok258',
#  'buoy': 'tok259',
#  'communications expert': 'tok260',
#  'joint chiefs of staff': 'tok261',
#  'crash landing': 'tok262',
#  'jet fighter pilot': 'tok263',
#  'navy lieutenant': 'tok264',
#  'permission to marry': 'tok265',
#  'uss john paul jones': 'tok266',
#  'based on board game': 'tok267',
#  'mighty mo': 'tok268',
#  'uss missouri': 'tok269',
#  'dna': 'tok270',
#  'tyrannosaurus rex': 'tok271',
#  'velociraptor': 'tok272',
#  'island': 'tok273',
#  'suspense': 'tok274',
#  'amusement park': 'tok275',
#  'animal attack': 'tok276',
#  'theme park': 'tok277',
#  'jurassic park': 'tok278',
#  'animal horror': 'tok279',
#  'sociopath': 'tok280',
#  'killer': 'tok281',
#  'art gallery': 'tok282',
#  'istanbul turkey': 'tok283',
#  'uzi': 'tok284',
#  'booby trap': 'tok285',
#  'impersonating a police officer': 'tok286',
#  'macao': 'tok287',
#  'pizza boy': 'tok288',
#  'doctor': 'tok289',
#  'tentacle': 'tok290',
#  'death': 'tok291',
#  'super villain': 'tok292',
#  'war on terror': 'tok293',
#  'tennessee': 'tok294',
#  'malibu': 'tok295',
#  'tony stark': 'tok296',
#  'iron man': 'tok297',
#  'mandarin': 'tok298',
#  'war machine': 'tok299',
#  'iron patriot': 'tok300',
#  'extremis': 'tok301',
#  'queen': 'tok302',
#  'alice in wonderland': 'tok303',
#  'mutant': 'tok304',
#  'beast': 'tok305',
#  'cyclops': 'tok306',
#  'dormitory': 'tok307',
#  'games': 'tok308',
#  'best friend': 'tok309',
#  'university': 'tok310',
#  'scary': 'tok311',
#  'egypt': 'tok312',
#  'sun': 'tok313',
#  'chaos': 'tok314',
#  'symbol': 'tok315',
#  'artifact': 'tok316',
#  'transformers': 'tok317',
#  'tank': 'tok318',
#  'robot': 'tok319',
#  'giant robot': 'tok320',
#  'transforming robot': 'tok321',
#  'circus': 'tok322',
#  'hope': 'tok323',
#  'illusion': 'tok324',
#  'lost': 'tok325',
#  'magic trick': 'tok326',
#  'obsession': 'tok327',
#  'electrocution': 'tok328',
#  'medical experiment': 'tok329',
#  'electricity': 'tok330',
#  'artificial intelligence': 'tok331',
#  'computer program': 'tok332',
#  'dystopia': 'tok333',
#  'computer': 'tok334',
#  'deception': 'tok335',
#  'duel': 'tok336',
#  'motorcycle': 'tok337',
#  'neon light': 'tok338',
#  'autocracy': 'tok339',
#  'car race': 'tok340',
#  'anthropomorphism': 'tok341',
#  'transformation': 'tok342',
#  'alien infection': 'tok343',
#  'magical object': 'tok344',
#  'protector': 'tok345',
#  'origin': 'tok346',
#  'college': 'tok347',
#  'toy': 'tok348',
#  'barbie': 'tok349',
#  'day care': 'tok350',
#  'teddy bear': 'tok351',
#  'toy comes to life': 'tok352',
#  'personification': 'tok353',
#  'inanimate objects coming to life': 'tok354',
#  'toy story': 'tok355',
#  'prophecy': 'tok356',
#  'san francisco': 'tok357',
#  'cyborg': 'tok358',
#  'killer robot': 'tok359',
#  'gas station': 'tok360',
#  'post-apocalyptic': 'tok361',
#  'army': 'tok362',
#  'firearm': 'tok363',
#  'wartime': 'tok364',
#  'los angeles': 'tok365',
#  'speed': 'tok366',
#  'car': 'tok367',
#  'race': 'tok368',
#  'muscle car': 'tok369',
#  'apocalypse': 'tok370',
#  'zombie': 'tok371',
#  'nuclear weapons': 'tok372',
#  'multiple perspectives': 'tok373',
#  'zombie apocalypse': 'tok374',
#  '1970s': 'tok375',
#  'storm': 'tok376',
#  'changing the past or future': 'tok377',
#  'spacecraft': 'tok378',
#  'friendship': 'tok379',
#  'space opera': 'tok380',
#  'terrorist bombing': 'tok381',
#  'giant': 'tok382',
#  'infidelity': 'tok383',
#  'persia': 'tok384',
#  'brother against brother': 'tok385',
#  'armageddon': 'tok386',
#  'regent': 'tok387',
#  'based on video game': 'tok388',
#  'giant monster': 'tok389',
#  'moon': 'tok390',
#  'bodyguard': 'tok391',
#  'based on cartoon': 'tok392',
#  'sabotage': 'tok393',
#  'word domination': 'tok394',
#  'commando': 'tok395',
#  'riddle': 'tok396',
#  'whip': 'tok397',
#  'treasure': 'tok398',
#  'mexico city': 'tok399',
#  'leather jacket': 'tok400',
#  'machinegun': 'tok401',
#  'alien phenomenons': 'tok402',
#  'maya civilization': 'tok403',
#  'peru': 'tok404',
#  'treasure hunt': 'tok405',
#  'nuclear explosion': 'tok406',
#  'refrigerator': 'tok407',
#  'archaeologist': 'tok408',
#  'indiana jones': 'tok409',
#  'archeology\xa0': 'tok410',
#  'friends': 'tok411',
#  'alternate history': 'tok412',
#  'fear': 'tok413',
#  'nature': 'tok414',
#  'human': 'tok415',
#  'journey': 'tok416',
#  'scotland': 'tok417',
#  'rebel': 'tok418',
#  'bravery': 'tok419',
#  'kingdom': 'tok420',
#  'wish': 'tok421',
#  'bear': 'tok422',
#  'scot': 'tok423',
#  'rebellious daughter': 'tok424',
#  'turns into animal': 'tok425',
#  'archery': 'tok426',
#  'ruins': 'tok427',
#  'peace offering': 'tok428',
#  'woman director': 'tok429',
#  'courage': 'tok430',
#  'stranded': 'tok431',
#  'hatred': 'tok432',
#  'romantic comedy': 'tok433',
#  'ambassador': 'tok434',
#  'civilization': 'tok435',
#  'natural disaster': 'tok436',
#  'end of the world': 'tok437',
#  'volcanic eruption': 'tok438',
#  'mayan': 'tok439',
#  'ark': 'tok440',
#  'solar': 'tok441',
#  'destruction  of mankind': 'tok442',
#  'holiday': 'tok443',
#  'victorian england': 'tok444',
#  'money': 'tok445',
#  'christmas eve': 'tok446',
#  'scrooge': 'tok447',
#  'christmas carol': 'tok448',
#  'ghost': 'tok449',
#  'lesson': 'tok450',
#  'charles dickens': 'tok451',
#  'christmas': 'tok452',
#  'jupiter': 'tok453',
#  'interspecies romance': 'tok454',
#  'africa': 'tok455',
#  'feral child': 'tok456',
#  'tarzan': 'tok457',
#  'jungle': 'tok458',
#  'self sacrifice': 'tok459',
#  'winter': 'tok460',
#  'cupboard': 'tok461',
#  'beaver': 'tok462',
#  'fairy-tale figure': 'tok463',
#  'supernatural powers': 'tok464',
#  'world domination': 'tok465',
#  '1980s': 'tok466',
#  'scarecrow': 'tok467',
#  'sadism': 'tok468',
#  'joker': 'tok469',
#  'organized crime': 'tok470',
#  'criminal mastermind': 'tok471',
#  'district attorney': 'tok472',
#  'age difference': 'tok473',
#  'central and south america': 'tok474',
#  'balloon': 'tok475',
#  'floating in the air': 'tok476',
#  'exploring': 'tok477',
#  'middle east': 'tok478',
#  'arms dealer': 'tok479',
#  'counter terrorism': 'tok480',
#  'agent coulson': 'tok481',
#  'library': 'tok482',
#  'clock': 'tok483',
#  'film director': 'tok484',
#  'key': 'tok485',
#  'boy': 'tok486',
#  'automaton': 'tok487',
#  'hiding': 'tok488',
#  'filmmaking': 'tok489',
#  'leg brace': 'tok490',
#  'doberman': 'tok491',
#  'based on tv series': 'tok492',
#  'steam locomotive': 'tok493',
#  'drag': 'tok494',
#  'shared universe': 'tok495',
#  'anti hero': 'tok496',
#  'secret mission': 'tok497',
#  'villain': 'tok498',
#  'supervillain': 'tok499',
#  'father son relationship': 'tok500',
#  'daily life': 'tok501',
#  'married couple': 'tok502',
#  'support': 'tok503',
#  'father': 'tok504',
#  'marriage': 'tok505',
#  'baustelle': 'tok506',
#  'rescue': 'tok507',
#  "noah's ark": 'tok508',
#  'deja vu': 'tok509',
#  'time warp': 'tok510',
#  'restart': 'tok511',
#  'military officer': 'tok512',
#  'exoskeleton': 'tok513',
#  'tattoo': 'tok514',
#  'water': 'tok515',
#  'doomsday': 'tok516',
#  'secret': 'tok517',
#  'technology': 'tok518',
#  'warhead': 'tok519',
#  'government': 'tok520',
#  'president': 'tok521',
#  'murder': 'tok522',
#  'attack': 'tok523',
#  'explosion': 'tok524',
#  'lasers': 'tok525',
#  'evil': 'tok526',
#  'cobra': 'tok527',
#  'dream': 'tok528',
#  'cartoon': 'tok529',
#  'imaginary friend': 'tok530',
#  'moving': 'tok531',
#  'kids': 'tok532',
#  'unicorn': 'tok533',
#  'emotions': 'tok534',
#  'snake': 'tok535',
#  'wolf': 'tok536',
#  'elephant': 'tok537',
#  'tiger': 'tok538',
#  'panther': 'tok539',
#  'remake': 'tok540',
#  'talking animal': 'tok541',
#  'talking to animals': 'tok542',
#  'immortality': 'tok543',
#  'forest': 'tok544',
#  'woman': 'tok545',
#  'eternal youth': 'tok546',
#  'snow white': 'tok547',
#  'evil queen': 'tok548',
#  'evil stepmother': 'tok549',
#  'imprisoned': 'tok550',
#  'sorceress': 'tok551',
#  'sleeping beauty': 'tok552',
#  'dark fantasy': 'tok553',
#  'adaptation': 'tok554',
#  'retelling': 'tok555',
#  'literary adaptation': 'tok556',
#  'leader': 'tok557',
#  'colony': 'tok558',
#  'woods': 'tok559',
#  'ape': 'tok560',
#  'monkey': 'tok561',
#  'medical research': 'tok562',
#  'plague': 'tok563',
#  'japan': 'tok564',
#  'suicide': 'tok565',
#  'samurai': 'tok566',
#  'based on true story': 'tok567',
#  'samurai sword': 'tok568',
#  'ronin': 'tok569',
#  'shogun': 'tok570',
#  'half breed': 'tok571',
#  'washington d.c.': 'tok572',
#  'captain america': 'tok573',
#  'political thriller': 'tok574',
#  'ogre': 'tok575',
#  'inventor': 'tok576',
#  'destiny': 'tok577',
#  'dreamer': 'tok578',
#  'futuristic car': 'tok579',
#  'futuristic city': 'tok580',
#  'brother brother relationship': 'tok581',
#  'hero': 'tok582',
#  'talent': 'tok583',
#  'another dimension': 'tok584',
#  'boy genius': 'tok585',
#  'hate': 'tok586',
#  'moral dilemma': 'tok587',
#  'teen superheroes': 'tok588',
#  'dead brother': 'tok589',
#  'support group': 'tok590',
#  'product placement': 'tok591',
#  'bullying': 'tok592',
#  'racing': 'tok593',
#  'arcade': 'tok594',
#  'medal': 'tok595',
#  'self esteem': 'tok596',
#  'curiosity': 'tok597',
#  'precocious child': 'tok598',
#  'first person shooter': 'tok599',
#  'glitch': 'tok600',
#  'carefree': 'tok601',
#  'video gamer': 'tok602',
#  'q*bert': 'tok603',
#  'interrupted wedding': 'tok604',
#  'social reject': 'tok605',
#  'santa claus': 'tok606',
#  'nerd': 'tok607',
#  'gift': 'tok608',
#  'bell': 'tok609',
#  'beard': 'tok610',
#  'north pole': 'tok611',
#  'chute': 'tok612',
#  'trestle': 'tok613',
#  'ticket': 'tok614',
#  'flying': 'tok615',
#  'blacksmith': 'tok616',
#  'arena': 'tok617',
#  'night': 'tok618',
#  'training': 'tok619',
#  'village': 'tok620',
#  'viking': 'tok621',
#  'ignorance': 'tok622',
#  'flight': 'tok623',
#  'nest': 'tok624',
#  'combat': 'tok625',
#  'well': 'tok626',
#  'warrior': 'tok627',
#  'man vs machine': 'tok628',
#  'sun glasses': 'tok629',
#  'nanotechnology': 'tok630',
#  'rocket launcher': 'tok631',
#  'firemen': 'tok632',
#  'veterinarian': 'tok633',
#  'fire engine': 'tok634',
#  'psychiatrist': 'tok635',
#  'spaceship': 'tok636',
#  'outer space': 'tok637',
#  'adventurer': 'tok638',
#  'single parent': 'tok639',
#  'nasa': 'tok640',
#  'expedition': 'tok641',
#  'wormhole': 'tok642',
#  'famine': 'tok643',
#  'black hole': 'tok644',
#  'race against time': 'tok645',
#  'quantum mechanics': 'tok646',
#  'family relationships': 'tok647',
#  'farmhouse': 'tok648',
#  'astronaut': 'tok649',
#  'father daughter relationship': 'tok650',
#  'single father': 'tok651',
#  'farmer': 'tok652',
#  'space station': 'tok653',
#  'astrophysics': 'tok654',
#  'zero gravity': 'tok655',
#  'time paradox': 'tok656',
#  'relativity': 'tok657',
#  'loss of lover': 'tok658',
#  'kidnapping': 'tok659',
#  'sleep': 'tok660',
#  'subconsciousness': 'tok661',
#  'heist': 'tok662',
#  'redemption': 'tok663',
#  'female hero': 'tok664',
#  'godzilla': 'tok665',
#  'kaiju': 'tok666',
#  'toyko': 'tok667',
#  'mountains': 'tok668',
#  'ring': 'tok669',
#  'goblin': 'tok670',
#  'tunnel': 'tok671',
#  'underground lake': 'tok672',
#  'buried treasure': 'tok673',
#  'climbing a tree': 'tok674',
#  'invisibility': 'tok675',
#  'ancient': 'tok676',
#  'gnomes': 'tok677',
#  'street gang': 'tok678',
#  'auto-tuning': 'tok679',
#  'automobile racing': 'tok680',
#  'diary': 'tok681',
#  'navy': 'tok682',
#  'funeral': 'tok683',
#  'tea': 'tok684',
#  'travel': 'tok685',
#  'hospital': 'tok686',
#  'cia': 'tok687',
#  'mine': 'tok688',
#  'historical fiction': 'tok689',
#  'nuclear war': 'tok690',
#  'cuban missile crisis': 'tok691',
#  'world war iii': 'tok692',
#  '1960s': 'tok693',
#  'revolution': 'tok694',
#  'game of death': 'tok695',
#  'fire': 'tok696',
#  'fountain': 'tok697',
#  'book': 'tok698',
#  'castle': 'tok699',
#  'apprentice': 'tok700',
#  'merlin': 'tok701',
#  'mission': 'tok702',
#  'sorcerer': 'tok703',
#  'apprendista': 'tok704',
#  'morgana': 'tok705',
#  "new year's eve": 'tok706',
#  'drowning': 'tok707',
#  'cataclysm': 'tok708',
#  'atlantic ocean': 'tok709',
#  'ball': 'tok710',
#  'self-abandonment': 'tok711',
#  'giant wave': 'tok712',
#  'blackout': 'tok713',
#  'single': 'tok714',
#  'capsized ship': 'tok715',
#  'mad hatter': 'tok716',
#  'ambush': 'tok717',
#  'sadness': 'tok718',
#  'stage': 'tok719',
#  'liberation of prisoners': 'tok720',
#  'prince': 'tok721',
#  'donkey': 'tok722',
#  'theatre play': 'tok723',
#  'conciliation': 'tok724',
#  'tricks': 'tok725',
#  'heir to the throne': 'tok726',
#  'assault': 'tok727',
#  'boarding school': 'tok728',
#  "coup d'etat": 'tok729',
#  'teacher': 'tok730',
#  'cowardliness': 'tok731',
#  'pregnancy': 'tok732',
#  'capture': 'tok733',
#  'video game': 'tok734',
#  'chase': 'tok735',
#  'fictional language': 'tok736',
#  'muscles': 'tok737',
#  'orc': 'tok738',
#  'fiction': 'tok739',
#  'good vs evil': 'tok740',
#  'king': 'tok741',
#  'knife held to throat': 'tok742',
#  'snowing': 'tok743',
#  'quest': 'tok744',
#  'nurse': 'tok745',
#  'patriotism': 'tok746',
#  'hawaii': 'tok747',
#  'world war ii': 'tok748',
#  'pilot': 'tok749',
#  'pearl harbor': 'tok750',
#  'u.s. air force': 'tok751',
#  'airplane': 'tok752',
#  'pin-up': 'tok753',
#  'destroy': 'tok754',
#  'based on toy': 'tok755',
#  'teenage hero': 'tok756',
#  'aristotle': 'tok757',
#  'greece': 'tok758',
#  'campaign': 'tok759',
#  'alexander the great': 'tok760',
#  'homosexuality': 'tok761',
#  'gay relationship': 'tok762',
#  'ancient world': 'tok763',
#  'cutting the cord': 'tok764',
#  'child hero': 'tok765',
#  'dying and death': 'tok766',
#  "sorcerer's apprentice": 'tok767',
#  'black magic': 'tok768',
#  'sorcery': 'tok769',
#  'occultism': 'tok770',
#  'chosen one': 'tok771',
#  'tournament': 'tok772',
#  'teenager': 'tok773',
#  'alcohol': 'tok774',
#  'forbidden love': 'tok775',
#  'lovers': 'tok776',
#  'affection': 'tok777',
#  'advertising expert': 'tok778',
#  'alcoholism': 'tok779',
#  'pokies': 'tok780',
#  'lost civilisation': 'tok781',
#  'alone': 'tok782',
#  'helplessness': 'tok783',
#  'virus': 'tok784',
#  'pandemic': 'tok785',
#  'london england': 'tok786',
#  'chocolate': 'tok787',
#  'factory worker': 'tok788',
#  'parents kids relationship': 'tok789',
#  'candy': 'tok790',
#  'overweight child': 'tok791',
#  'grandfather grandson relationship': 'tok792',
#  'paris': 'tok793',
#  'expensive restaurant': 'tok794',
#  'river': 'tok795',
#  'cook': 'tok796',
#  'mouse': 'tok797',
#  'confidence': 'tok798',
#  'roof': 'tok799',
#  'window': 'tok800',
#  "leaving one's family": 'tok801',
#  'work': 'tok802',
#  'restaurant critic': 'tok803',
#  'kitchen': 'tok804',
#  'spice': 'tok805',
#  'court': 'tok806',
#  'cookbook': 'tok807',
#  'chef': 'tok808',
#  'rat': 'tok809',
#  'himalaya': 'tok810',
#  'martial arts': 'tok811',
#  'rivalry': 'tok812',
#  'ninja': 'tok813',
#  'haunted by the past': 'tok814',
#  'evil doctor': 'tok815',
#  'escapade': 'tok816',
#  'master villain': 'tok817',
#  'fighting crime': 'tok818',
#  'unfulfillment': 'tok819',
#  'love and romance': 'tok820',
#  'unfulfilled love': 'tok821',
#  'jealousy': 'tok822',
#  'dance': 'tok823',
#  'hunger': 'tok824',
#  'zoo': 'tok825',
#  'hippopotamus': 'tok826',
#  'chimp': 'tok827',
#  'penguin': 'tok828',
#  'volcano': 'tok829',
#  'madagascar': 'tok830',
#  'zebra': 'tok831',
#  'shark': 'tok832',
#  'museum': 'tok833',
#  'theodore roosevelt': 'tok834',
#  'amelia earhart': 'tok835',
#  'smithsonian': 'tok836',
#  'boxer': 'tok837',
#  'philosophy': 'tok838',
#  'kung fu': 'tok839',
#  'underground world': 'tok840',
#  'temple': 'tok841',
#  'subway': 'tok842',
#  'sunlight': 'tok843',
#  'computer virus': 'tok844',
#  'precognition': 'tok845',
#  'super computer': 'tok846',
#  'machine town': 'tok847',
#  'ying yang': 'tok848',
#  'virtual reality': 'tok849',
#  'world religion': 'tok850',
#  'truth': 'tok851',
#  'cyberpunk': 'tok852',
#  'yin yang': 'tok853',
#  'gnosticism': 'tok854',
#  'betrayal': 'tok855',
#  'snowman': 'tok856',
#  'reindeer': 'tok857',
#  'curse': 'tok858',
#  'snow': 'tok859',
#  'troll': 'tok860',
#  'mountain climber': 'tok861',
#  'plato': 'tok862',
#  'rave': 'tok863',
#  'hostile takeover': 'tok864',
#  'norse mythology': 'tok865',
#  'asgard': 'tok866',
#  'australia': 'tok867',
#  'survival': 'tok868',
#  'on the run': 'tok869',
#  'convoy': 'tok870',
#  'peak oil': 'tok871',
#  'dark future': 'tok872',
#  'rome': 'tok873',
#  'vatican': 'tok874',
#  'symbolism': 'tok875',
#  'christian': 'tok876',
#  'illuminati': 'tok877',
#  'prequel': 'tok878',
#  'anti matter': 'tok879',
#  'conspiracy': 'tok880',
#  'investigator': 'tok881',
#  'catholicism': 'tok882',
#  'cern': 'tok883',
#  'new mexico': 'tok884',
#  'banishment': 'tok885',
#  'hammer': 'tok886',
#  'odin': 'tok887',
#  'heimdall': 'tok888',
#  'hamster': 'tok889',
#  'kids and family': 'tok890',
#  'cat vs dog': 'tok891',
#  'dog cat friendship': 'tok892',
#  'animal lead': 'tok893',
#  'girl dog relationship': 'tok894',
#  'dyr': 'tok895',
#  'underworld': 'tok896',
#  'hades': 'tok897',
#  'mythology': 'tok898',
#  'greek mythology': 'tok899',
#  'zeus': 'tok900',
#  'perseus': 'tok901',
#  'gods': 'tok902',
#  'ancient greece': 'tok903',
#  'based on greek myth': 'tok904',
#  'ares': 'tok905',
#  'imprisonment': 'tok906',
#  'vampire': 'tok907',
#  'fish out of water': 'tok908',
#  'chains': 'tok909',
#  'gothic': 'tok910',
#  'madness': 'tok911',
#  'old house': 'tok912',
#  'lost love': 'tok913',
#  'angry mob': 'tok914',
#  '18th century': 'tok915',
#  'hidden room': 'tok916',
#  'old mansion': 'tok917',
#  'austria': 'tok918',
#  'vienna opera': 'tok919',
#  'vienna': 'tok920',
#  'rural setting': 'tok921',
#  'tennis': 'tok922',
#  'flower': 'tok923',
#  'florist': 'tok924',
#  'flower shop': 'tok925',
#  'beehive': 'tok926',
#  'fleet': 'tok927',
#  'panda': 'tok928',
#  'ice': 'tok929',
#  'war ship': 'tok930',
#  'arrest': 'tok931',
#  'avatar': 'tok932',
#  'air': 'tok933',
#  'spirit': 'tok934',
#  'world': 'tok935',
#  'domination': 'tok936',
#  'cheering': 'tok937',
#  'berlin': 'tok938',
#  'white house': 'tok939',
#  'explosive': 'tok940',
#  'mobile phone': 'tok941',
#  'map': 'tok942',
#  'mask': 'tok943',
#  'honeymoon': 'tok944',
#  'shanghai': 'tok945',
#  'pretended murder': 'tok946',
#  'letter': 'tok947',
#  'covered investigation': 'tok948',
#  'to shoot dead': 'tok949',
#  'video': 'tok950',
#  'stamp': 'tok951',
#  'hard drive': 'tok952',
#  'e-mail': 'tok953',
#  'decipherment': 'tok954',
#  'suitcase': 'tok955',
#  'disguise': 'tok956',
#  'celebration': 'tok957',
#  'good and bad': 'tok958',
#  'research laboratory': 'tok959',
#  'blast': 'tok960',
#  'usa president': 'tok961',
#  'secret service': 'tok962',
#  'the white house': 'tok963',
#  'alien abduction': 'tok964',
#  "based on children's book": 'tok965',
#  'return': 'tok966',
#  'frog': 'tok967',
#  'girlfriend': 'tok968',
#  'rubin': 'tok969',
#  'peter pan': 'tok970',
#  'intelligence': 'tok971',
#  'adoption': 'tok972',
#  'child prodigy': 'tok973',
#  'growing up': 'tok974',
#  'children': 'tok975',
#  'talking dog': 'tok976',
#  'dog': 'tok977',
#  'first love': 'tok978',
#  'ancient egypt': 'tok979',
#  'time traveler': 'tok980',
#  'new school': 'tok981',
#  'george washington': 'tok982',
#  'gags': 'tok983',
#  'trouble': 'tok984',
#  'prodigy': 'tok985',
#  'adultery': 'tok986',
#  'beauty': 'tok987',
#  'trojan war': 'tok988',
#  'wall': 'tok989',
#  'fraud': 'tok990',
#  'sword fight': 'tok991',
#  'battlefield': 'tok992',
#  'pyre': 'tok993',
#  'trojan horse': 'tok994',
#  'trojan': 'tok995',
#  'bronze age': 'tok996',
#  'sparta greece': 'tok997',
#  'helen of troy': 'tok998',
#  "homer's iliad": 'tok999',
#  ...}

# %%
def tokenize(row):
    arr = []
    for item in row:
        arr.append(value_to_token[item])
    return arr

# %%
dataset['genres'] = dataset['genres'].apply(tokenize)
dataset['keywords'] = dataset['keywords'].apply(tokenize)
dataset['original_language'] = dataset['original_language'].apply(tokenize)
dataset.head()
# Out:
#                      genres  \
# 0  [tok0, tok1, tok2, tok3]
# 1        [tok1, tok2, tok0]
# 2        [tok0, tok1, tok4]
# 3  [tok0, tok4, tok5, tok6]
# 4        [tok0, tok1, tok3]
#
#                                             keywords original_language
# 0  [tok20, tok21, tok22, tok23, tok24, tok25, tok...         [tok9813]
# 1  [tok40, tok41, tok42, tok43, tok44, tok45, tok...         [tok9813]
# 2  [tok56, tok57, tok58, tok59, tok60, tok61, tok62]         [tok9813]
# 3  [tok63, tok64, tok65, tok66, tok67, tok68, tok...         [tok9813]
# 4  [tok57, tok84, tok85, tok25, tok86, tok28, tok...         [tok9813]

# %%
dataset = dataset.apply(lambda row: np.concatenate((row['genres'], row['keywords'], row['original_language'])), axis=1)
dataset.head()
# Out:
# 0    [tok0, tok1, tok2, tok3, tok20, tok21, tok22, ...
# 1    [tok1, tok2, tok0, tok40, tok41, tok42, tok43,...
# 2    [tok0, tok1, tok4, tok56, tok57, tok58, tok59,...
# 3    [tok0, tok4, tok5, tok6, tok63, tok64, tok65, ...
# 4    [tok0, tok1, tok3, tok57, tok84, tok85, tok25,...
# dtype: object

# %%
dataset_bkp['movie_desc'] = dataset.apply(lambda row: ' '.join(row))
dataset_bkp.to_csv('processed_movie_details.csv', index=False)

token_to_value_json = json.dumps(token_to_value)
value_to_token_json = json.dumps(value_to_token)

f = open('token_to_value.json','w')
f.write(token_to_value_json)
f.close()

f = open('value_to_token.json','w')
f.write(value_to_token_json)
f.close()

# %% [markdown]
# ### Generating Synthetic data

# %% [markdown]
# Let's assume we take last 10 movies from user's history to get his current choice

# %%
random.seed = 30
max_movies_per_person = 10
len_movie_list = dataset.shape[0]
synthetic_dataset = []

# %%
for i in range(15000):
    history = []
    for j in range(random.randint(1, max_movies_per_person)):
        history += list(dataset[random.randint(0, len_movie_list - 1)])
    
#     history = list(dict.fromkeys(history))
    synthetic_dataset.append(history)

# %%
pd.Series(synthetic_dataset).apply(lambda row: ' '.join(row)).to_csv('user_data.csv', header='user_history', index=False)
